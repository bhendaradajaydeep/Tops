# %%
1.# Define a function called calculate_final_price(price, discount_rate) that returns the final price after applying the discount.
# Test it with price 1200 and discount_rate 0.15

def calculate_final_price(price, discount_rate):
    final_pric = price - price*discount_rate/100
    return final_pric

price = int (input("Enter a price"))
discount_rate = float(input("Enter a discount rate:"))

calculate_final_price(price,discount_rate)
# Out:
# 850.0

# %%
2.
# Create a function get_delivery_charge(amount, city='Ahmedabad') that returns a delivery charge:  for AhmedabRs. 30ad,
# Rs. 50 for other cities. Call it with and without the city argument to see both results.

def get_delivery_charge(city='Ahmedabad'):
    if city == "Ahmedabad":
        return"delivery charge for AhmedabRs is .:30RS "
    else:
        return"delivery charge for  your add is Rs.:50RS  "
     
print(get_delivery_charge("surat"))
print(get_delivery_charge())
# Out:
# delivery charge for  your add is Rs.:50RS
# delivery charge for AhmedabRs is .:30RS

# %%
3.
# Build a function called format_coupon_message(username, discount=10) that returns a string like 'Hi Rahul, you get 10% off!' If no discount
# is given, use 10% by default. Test it for two users: one with a custom discount, one with the default.


def format_coupon_message(username, discount=10):
    print(f"'Hi {username}, you get {discount}% off!")


format_coupon_message("jaydeep")
format_coupon_message("shayam",20)
# Out:
# 'Hi jaydeep, you get 10% off!
# 'Hi shayam, you get 20% off!

# %%
# 4.# Given a function apply_discount(price, rate=0.10), update it so that if the rate is not passed, it uses 0.10 by default. Then,
# call it with only the price argument and print the result.

def apply_discount(price, rate=10):
    print(f"your price is {price} and your discount rate {rate}% and Final amount is : {price-price*rate/100}")

apply_discount(2000,20)
apply_discount(2000)
# Out:
# your price is 2000 and your discount rate 20% and Final amount is : 1600.0
# your price is 2000 and your discount rate 10% and Final amount is : 1800.0

# %%
# Write a function called calculate_cashback(amount, cashback_rate=0.05) that returns the cashback amount.
# Then, use it to calculate cashback for a Zomato order of Rs. 500 with the default rate, and for a Flipkart order of Rs.
# 2000 with a 7% cashback.


def calculate_cashback(amount, cashback_rate=5):
    print(f"your price is {amount} and cashback rate is {cashback_rate}% your cashback amount is {amount*cashback_rate/100} ")
    
print("zometo",calculate_cashback(2000))
print("flipkart",calculate_cashback(2000,7))
# Out:
# your price is 2000 and cashback rate is 5% your cashback amount is 100.0
# zometo None
# your price is 2000 and cashback rate is 7% your cashback amount is 140.0
# flipkart None
