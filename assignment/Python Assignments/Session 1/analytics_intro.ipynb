# %%
2.# Create a new Jupyter Notebook file named analytics_intro.ipynb and write a cell that prints your name and your favorite app 
# (like Instagram or Zomato) using the print() function.


print("Hello jaydeep")
print("FaceBook")
# Out:
# Hello jaydeep
# FaceBook

# %%
# 4.# In Jupyter Notebook, add a new cell and write Python code to print the current year using the datetime module.

from datetime import datetime

# Get the current date and time
current_datetime = datetime.now()

# Print the current date and time
print("Current Date and Time:", current_datetime)
# Out:
# Current Date and Time: 2026-07-21 15:33:31.524717
