# %%
# 1.Create three variables in Python: user_name, fav_app, and daily_usage_hours.

user_name ="jaydeep"
fav_app ="Face Book"
daily_usage_hours="1.5 Hours"

print(f"my name is {user_name} my fav app name is {fav_app} i spend {daily_usage_hours} on {fav_app}")
# Out:
# my name is jaydeep my fav app name is Face Book i spend 1.5 Hours on Face Book

# %%
# 2.Write a Python script that declares variables for product_name, price, and is_available to represent an item on Flipkart. Print each variable
# and its data type using the type() function.

product_name="leptop"
price=12345
is_available=True

print(type(product_name),type(price),type(is_available))
# Out:
# <class 'str'> <class 'int'> <class 'bool'>

# %%
# 3.Demonstrate the difference between single-line and multi-line comments in Python by writing a script that explains how a 
# Spotify playlist recommendation system might work.for single-line and triple quotes for multi-line comments.

# Spotify Playlist Recommendation System
# This is a single-line comment.
# It explains one idea in a single line.

"""
This is a multi-line comment.
A Spotify playlist recommendation system may work by:
1. Collecting the user's listening history.
2. Analyzing favorite artists, genres, and songs.
3. Comparing the user's preferences with similar users.
4. Recommending songs and playlists based on patterns,
   popularity, and machine learning algorithms.
"""

print("Spotify Playlist Recommendation System")
print("Recommendations are generated based on your listening habits and preferences.")

# %%
# 4.Create variables for order_total, delivery_region, and discount_percent to represent a Zomato order. 
# Follow Python naming conventions and print a sentence using all three variables, like
# 'Order from [region] totals ₹[order_total] with [discount_percent]% discount.'

order_total=12345
delivery_region="west"
discount_percent=10
print(f"Order from {delivery_region} totals ₹{order_total} with {discount_percent}% discount.")
# Out:
# Order from west totals ₹12345 with 10% discount.

# %%
# 5.Write a Python script that intentionally mixes tabs and spaces for indentation


# print("Start")
# if True:
# 	print("This line uses a tab")
#     print("This line uses spaces")  # Indentation error 


print("Start")

if True:
    print("This line uses spaces")
    print("This line also uses spaces")

print("Program executed successfully!")
# Out:
# Start
# This line uses spaces
# This line also uses spaces
# Program executed successfully!
